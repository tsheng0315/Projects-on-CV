# %% [markdown]
# # Covid19 Data Analysis
# ------------------------------------------

# %% [markdown]
# ### Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1

# %% [markdown]
# ### Task 1.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
url = 'https://raw.githubusercontent.com/tsheng0315/Projects-on-CV/main/COVID-19%20Data%20Analysis/Dataset/covid19_Confirmed_dataset.csv'
df_Confirmed = pd.read_csv(url)
df_Confirmed.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...     1939     2171
# 1                           NaN              Albania  ...      766      773
# 2                           NaN              Algeria  ...     3848     4006
# 3                           NaN              Andorra  ...      743      745
# 4                           NaN               Angola  ...       27       27
# 5                           NaN  Antigua and Barbuda  ...       24       24
# 6                           NaN            Argentina  ...     4285     4428
# 7                           NaN              Armenia  ...     1932     2066
# 8  Australian Capital Territory            Australia  ...      106      106
# 9               New South Wales            Australia  ...     3016     3025
#
# [10 rows x 104 columns]

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
df_Confirmed.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
#df=df_Confirmed.drop(['Lat','Long'], axis=1) # return a copy 
df_Confirmed.drop(['Lat','Long'], axis=1,inplace=True) # change on the original data frame
df_Confirmed.head(10)
df_Confirmed[df_Confirmed['Country/Region']=='China']
# Out:
#     Province/State Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 49           Anhui          China        1  ...      991      991      991
# 50         Beijing          China       14  ...      593      593      593
# 51       Chongqing          China        6  ...      579      579      579
# 52          Fujian          China        1  ...      355      355      356
# 53           Gansu          China        0  ...      139      139      139
# 54       Guangdong          China       26  ...     1588     1588     1588
# 55         Guangxi          China        2  ...      254      254      254
# 56         Guizhou          China        1  ...      147      147      147
# 57          Hainan          China        4  ...      168      168      168
# 58           Hebei          China        1  ...      328      328      328
# 59    Heilongjiang          China        0  ...      939      939      944
# 60           Henan          China        5  ...     1276     1276     1276
# 61       Hong Kong          China        0  ...     1037     1037     1037
# 62           Hubei          China      444  ...    68128    68128    68128
# 63           Hunan          China        4  ...     1019     1019     1019
# 64  Inner Mongolia          China        0  ...      199      200      201
# 65         Jiangsu          China        1  ...      653      653      653
# 66         Jiangxi          China        2  ...      937      937      937
# 67           Jilin          China        0  ...      110      111      111
# 68        Liaoning          China        2  ...      146      146      146
# 69           Macau          China        1  ...       45       45       45
# 70         Ningxia          China        1  ...       75       75       75
# 71         Qinghai          China        0  ...       18       18       18
# 72         Shaanxi          China        0  ...      306      306      306
# 73        Shandong          China        2  ...      787      787      787
# 74        Shanghai          China        9  ...      645      647      652
# 75          Shanxi          China        1  ...      197      197      197
# 76         Sichuan          China        5  ...      561      561      561
# 77         Tianjin          China        4  ...      190      190      190
# 78           Tibet          China        0  ...        1        1        1
# 79        Xinjiang          China        0  ...       76       76       76
# 80          Yunnan          China        1  ...      185      185      185
# 81        Zhejiang          China       10  ...     1268     1268     1268
#
# [33 rows x 102 columns]

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
df_Confirmed_aggr=df_Confirmed.groupby('Country/Region').sum()
df_Confirmed_aggr.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1828     1939     2171
# Albania               0        0        0  ...      750      766      773
# Algeria               0        0        0  ...     3649     3848     4006
# Andorra               0        0        0  ...      743      743      745
# Angola                0        0        0  ...       27       27       27
#
# [5 rows x 100 columns]

# %%
df_Confirmed_aggr.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China, Italy and the UK
# visualization always helps for better understanding of our data.

# %%
# df_Confirmed_aggr[df_Confirmed_aggr['Country/Region']=='China']
# after aggregate, column name 'Country/Region' no longer exists
df_Confirmed_aggr.loc['China'].plot()
df_Confirmed_aggr.loc['Italy'].plot()
df_Confirmed_aggr.loc['United Kingdom'].plot()

plt.legend()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
df_Confirmed_aggr.loc['China'].plot()

# %%
df_Confirmed_aggr.loc['China'][:3].plot()
# first three days' cases

# %% [markdown]
# ### task 3.1: caculating the new infections in China (first derivative of the sum curve)

# %%
df_Confirmed_aggr.loc['China'].diff().plot()

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China, Italy and the UK

# %%
df_Confirmed_aggr.loc['China'].diff().max()
# Out:
# 15136.0

# %%
df_Confirmed_aggr.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
df_Confirmed_aggr.loc['United Kingdom'].diff().max()
# Out:
# 8733.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries=df_Confirmed_aggr.index
max_infection_rate=[]
for i in countries:
  MIR=df_Confirmed_aggr.loc[i].diff().max()
  max_infection_rate.append(MIR)
df_Confirmed_aggr['Max Infection Rate']=max_infection_rate

# %%
df_Confirmed_aggr.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  Max Infection Rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1939     2171               232.0
# Albania               0        0        0  ...      766      773                34.0
# Algeria               0        0        0  ...     3848     4006               199.0
# Andorra               0        0        0  ...      743      745                43.0
# Angola                0        0        0  ...       27       27                 5.0
#
# [5 rows x 101 columns]

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
covid_data=pd.DataFrame(df_Confirmed_aggr['Max Infection Rate'])
# the index will appear automatically

# %%
covid_data.head()
# Out:
#                 Max Infection Rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
url='https://raw.githubusercontent.com/tsheng0315/Projects-on-CV/main/COVID-19%20Data%20Analysis/Dataset/worldwide_happiness_report.csv'
df_happiness_report=pd.read_csv(url)

# %%
df_happiness_report.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
useless_cols=['Overall rank','Score','Generosity','Perceptions of corruption']

# %%
df_happiness_report.drop(useless_cols,axis=1,inplace=True)
df_happiness_report.head()
# Out:
#   Country or region  ...  Freedom to make life choices
# 0           Finland  ...                         0.596
# 1           Denmark  ...                         0.592
# 2            Norway  ...                         0.603
# 3           Iceland  ...                         0.591
# 4       Netherlands  ...                         0.557
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe to country names

# %%
df_happiness_report.set_index('Country or region',inplace=True)
df_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
covid_data.head()
# Out:
#                 Max Infection Rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %%
covid_data.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
df_happiness_report.head()
# Out:
#                    GDP per capita  ...  Freedom to make life choices
# Country or region                  ...
# Finland                     1.340  ...                         0.596
# Denmark                     1.383  ...                         0.592
# Norway                      1.488  ...                         0.603
# Iceland                     1.380  ...                         0.591
# Netherlands                 1.396  ...                         0.557
#
# [5 rows x 4 columns]

# %%
df_happiness_report.shape
# Out:
# (156, 4)

# %%
# 187 countries > 156 countries->> inner join
data=covid_data.join(df_happiness_report, how='inner')
data.head()
# Out:
#              Max Infection Rate  ...  Freedom to make life choices
# Afghanistan               232.0  ...                         0.000
# Albania                    34.0  ...                         0.383
# Algeria                   199.0  ...                         0.086
# Argentina                 291.0  ...                         0.471
# Armenia                   134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data.corr()
# Out:
#                               Max Infection Rate  ...  Freedom to make life choices
# Max Infection Rate                      1.000000  ...                      0.078196
# GDP per capita                          0.250118  ...                      0.394603
# Social support                          0.191958  ...                      0.456246
# Healthy life expectancy                 0.289263  ...                      0.427892
# Freedom to make life choices            0.078196  ...                      1.000000
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.head()
# Out:
#              Max Infection Rate  ...  Freedom to make life choices
# Afghanistan               232.0  ...                         0.000
# Albania                    34.0  ...                         0.383
# Algeria                   199.0  ...                         0.086
# Argentina                 291.0  ...                         0.471
# Armenia                   134.0  ...                         0.283
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x= data['GDP per capita']
y=data['Max Infection Rate']
sns.scatterplot(x,y)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# as GDP per capita grows, the max infection rate grows. But doesn't show enough details in y axis. So we use log in y axis.

# %%
x= data['GDP per capita']
y=data['Max Infection Rate']
sns.scatterplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x= data['Social support']
y=data['Max Infection Rate']
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x= data['Healthy life expectancy']
y=data['Max Infection Rate']
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x= data['Freedom to make life choices']
y=data['Max Infection Rate']
sns.regplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# From the graph, it seems the infection rate in well developed countries are higher. But people may say it is because in developing countries many cases haven't been detected. So we turn to death rate for help.

# %%
url = 'https://raw.githubusercontent.com/tsheng0315/Projects-on-CV/main/COVID-19%20Data%20Analysis/Dataset/covid19_deaths_dataset.csv'
df_death = pd.read_csv(url)
df_death.head(10)
# Out:
#                  Province/State       Country/Region  ...  4/29/20  4/30/20
# 0                           NaN          Afghanistan  ...       60       64
# 1                           NaN              Albania  ...       30       31
# 2                           NaN              Algeria  ...      444      450
# 3                           NaN              Andorra  ...       42       42
# 4                           NaN               Angola  ...        2        2
# 5                           NaN  Antigua and Barbuda  ...        3        3
# 6                           NaN            Argentina  ...      214      218
# 7                           NaN              Armenia  ...       30       32
# 8  Australian Capital Territory            Australia  ...        3        3
# 9               New South Wales            Australia  ...       40       41
#
# [10 rows x 104 columns]

# %%
drop_cols_death=['Lat','Long']
df_death.drop(drop_cols_death,axis=1,inplace=True)
df_death.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  4/28/20  4/29/20  4/30/20
# 0            NaN    Afghanistan        0  ...       58       60       64
# 1            NaN        Albania        0  ...       30       30       31
# 2            NaN        Algeria        0  ...      437      444      450
# 3            NaN        Andorra        0  ...       41       42       42
# 4            NaN         Angola        0  ...        2        2        2
#
# [5 rows x 102 columns]

# %%
df_death_agg=df_death.groupby('Country/Region').sum()
df_death_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/28/20  4/29/20  4/30/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...       58       60       64
# Albania               0        0        0  ...       30       30       31
# Algeria               0        0        0  ...      437      444      450
# Andorra               0        0        0  ...       41       42       42
# Angola                0        0        0  ...        2        2        2
#
# [5 rows x 100 columns]

# %%
countries_death=df_death_agg.index
max_death_rate=[]
for i in countries_death:
  MIR=df_death_agg.loc[i].diff().max()
  max_death_rate.append(MIR)
df_death_agg['Max Death Rate']=max_death_rate
df_death_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  4/29/20  4/30/20  Max Death Rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...       60       64             7.0
# Albania               0        0        0  ...       30       31             4.0
# Algeria               0        0        0  ...      444      450            30.0
# Andorra               0        0        0  ...       42       42             4.0
# Angola                0        0        0  ...        2        2             2.0
#
# [5 rows x 101 columns]

# %%
covid_death=pd.DataFrame(df_death_agg['Max Death Rate'])
covid_death.head()
# the index will appear automatically
# Out:
#                 Max Death Rate
# Country/Region
# Afghanistan                7.0
# Albania                    4.0
# Algeria                   30.0
# Andorra                    4.0
# Angola                     2.0

# %%
covid_death.shape
# Out:
# (187, 1)

# %%
df_happiness_report.shape
# Out:
# (156, 4)

# %%
# 187 countries > 156 countries->> inner join
death_happiness=covid_death.join(df_happiness_report, how='inner')
death_happiness.head()
# Out:
#              Max Death Rate  ...  Freedom to make life choices
# Afghanistan             7.0  ...                         0.000
# Albania                 4.0  ...                         0.383
# Algeria                30.0  ...                         0.086
# Argentina              13.0  ...                         0.471
# Armenia                 3.0  ...                         0.283
#
# [5 rows x 5 columns]

# %%
fig, (ax1, ax2,ax3) = plt.subplots(1,3,figsize=(15,3))
x=death_happiness['GDP per capita']
y=death_happiness['Max Death Rate']
x2=death_happiness['Social support']
y2=death_happiness['Max Death Rate']

x3=death_happiness['Freedom to make life choices']
y3=death_happiness['Max Death Rate']

sns.regplot(x, y,ax=ax1)
sns.regplot(x2, y2,ax=ax2)
sns.regplot(x3, y3,ax=ax3)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x=death_happiness['GDP per capita']
y=death_happiness['Max Death Rate']
sns.regplot(x, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x=death_happiness['Social support']
y=death_happiness['Max Death Rate']
sns.regplot(x, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x=death_happiness['Healthy life expectancy']
y=death_happiness['Max Death Rate']
sns.regplot(x, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x=death_happiness['Freedom to make life choices']
y=death_happiness['Max Death Rate']
sns.regplot(x, y)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
